# %% [markdown]
# <a href="https://colab.research.google.com/github/anaferreira744/DE-DP-ADF/blob/main/1_read_write_stream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read & Write Stream
# - readStream()
# - writeStream()
# - Streaming Dataframe

# %% [markdown]
# # Setting up PySpark

# %%
# %pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.master('local').appName('Test streaming').getOrCreate()

# %% [markdown]
# # readStream with format "rate"
# - readStream
# - format("rate")

# %%
import pyspark.sql.functions as F

# read stream
stream = spark.readStream.format("rate").load()

# %%
type(stream)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# checking if it's streaming dataframe
stream.isStreaming
# Out:
# True

# %%
# should be false
data = [("c1", "v1"), ("c2", "v2")]
columns = ["col1", "col2"]
df = spark.createDataFrame(data, columns)
df.isStreaming
# Out:
# False

# %%
# apply normal dataframe operations
stream.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: long (nullable = true)

# %%
# Queries with streaming sources must be executed with writeStream.start();
# stream.show()
stream.count()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-2c876bdc4c4f> in <cell line: 3>()
#       1 # Queries with streaming sources must be executed with writeStream.start();
#       2 # stream.show()
# ----> 3 stream.count()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in count(self)
#    1238         3
#    1239         """
# -> 1240         return int(self._jdf.count())
#    1241
#    1242     def collect(self) -> List[Row]:
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320
#    1321         answer = self.gateway_client.send_command(command)
# -> 1322         return_value = get_return_value(
#    1323             answer, self.gateway_client, self.target_id, self.name)
#    1324
#
# /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py in deco(*a, **kw)
#     183                 # Hide where the exception came from that shows a non-Pythonic
#     184                 # JVM exception message.
# --> 185                 raise converted from None
#     186             else:
#     187                 raise
#
# AnalysisException: Queries with streaming sources must be executed with writeStream.start();
# rate

# %% [markdown]
# # Transfor streaming dataframe

# %%
transformed = stream.withColumn("value2", F.col("value") * 2)

# %%
transformed.isStreaming
# Out:
# True

# %% [markdown]
# # write streaming dataframe - format memory
# - writeStream
# - format("memory")
# - queryName
# - outputMode
# - start

# %%
query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report')
  .outputMode('append')
  .start()
)

# %% [markdown]
# # Checking result table

# %%
# StreamingQuery
type(query)
# Out:
# pyspark.sql.streaming.query.StreamingQuery

# %%
print(spark.table("rate_report").count())
spark.table("rate_report").show(20, False)

# one line per second
# Out:
# 10
# +-----------------------+-----+------+
# |timestamp              |value|value2|
# +-----------------------+-----+------+
# |2024-11-23 14:01:32.311|0    |0     |
# |2024-11-23 14:01:33.311|1    |2     |
# |2024-11-23 14:01:34.311|2    |4     |
# |2024-11-23 14:01:35.311|3    |6     |
# |2024-11-23 14:01:36.311|4    |8     |
# |2024-11-23 14:01:37.311|5    |10    |
# |2024-11-23 14:01:38.311|6    |12    |
# |2024-11-23 14:01:39.311|7    |14    |
# |2024-11-23 14:01:40.311|8    |16    |
# |2024-11-23 14:01:41.311|9    |18    |
# |2024-11-23 14:01:42.311|10   |20    |
# |2024-11-23 14:01:43.311|11   |22    |
# |2024-11-23 14:01:44.311|12   |24    |
# |2024-11-23 14:01:45.311|13   |26    |
# +-----------------------+-----+------+

# %%
query.status
# Out:
# {'message': 'Waiting for data to arrive',
#  'isDataAvailable': False,
#  'isTriggerActive': False}

# %%
query.isActive
# Out:
# True

# %%
query.recentProgress
# Out:
# [{'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:11.311Z',
#   'batchId': 398,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.76470588235294,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 85,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 398,
#     'endOffset': 399,
#     'latestOffset': 399,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.76470588235294}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:12.312Z',
#   'batchId': 399,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 399,
#     'endOffset': 400,
#     'latestOffset': 400,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:13.311Z',
#   'batchId': 400,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 6.802721088435375,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 68,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 147,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 400,
#     'endOffset': 401,
#     'latestOffset': 401,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 6.802721088435375}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:14.319Z',
#   'batchId': 401,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 39,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 92,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 401,
#     'endOffset': 402,
#     'latestOffset': 402,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:15.315Z',
#   'batchId': 402,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 38,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 103,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 402,
#     'endOffset': 403,
#     'latestOffset': 403,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:16.312Z',
#   'batchId': 403,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.11111111111111,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 90,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 403,
#     'endOffset': 404,
#     'latestOffset': 404,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.11111111111111}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:17.317Z',
#   'batchId': 404,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.638297872340425,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 37,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 94,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 404,
#     'endOffset': 405,
#     'latestOffset': 405,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.638297872340425}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:18.314Z',
#   'batchId': 405,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 76,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 405,
#     'endOffset': 406,
#     'latestOffset': 406,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:19.314Z',
#   'batchId': 406,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.090909090909092,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 110,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 406,
#     'endOffset': 407,
#     'latestOffset': 407,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.090909090909092}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:20.317Z',
#   'batchId': 407,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 9,
#    'triggerExecution': 119,
#    'walCommit': 40},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 407,
#     'endOffset': 408,
#     'latestOffset': 408,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:21.318Z',
#   'batchId': 408,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 54,
#    'commitOffsets': 34,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 119,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 408,
#     'endOffset': 409,
#     'latestOffset': 409,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:22.311Z',
#   'batchId': 409,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 77,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 409,
#     'endOffset': 410,
#     'latestOffset': 410,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:23.311Z',
#   'batchId': 410,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 410,
#     'endOffset': 411,
#     'latestOffset': 411,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:24.311Z',
#   'batchId': 411,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.363636363636365,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 88,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 411,
#     'endOffset': 412,
#     'latestOffset': 412,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.363636363636365}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:25.312Z',
#   'batchId': 412,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.76470588235294,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 85,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 412,
#     'endOffset': 413,
#     'latestOffset': 413,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.76470588235294}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:26.312Z',
#   'batchId': 413,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.708737864077671,
#   'durationMs': {'addBatch': 31,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 103,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 413,
#     'endOffset': 414,
#     'latestOffset': 414,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.708737864077671}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:27.319Z',
#   'batchId': 414,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.771929824561402,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 59,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 114,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 414,
#     'endOffset': 415,
#     'latestOffset': 415,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.771929824561402}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:28.318Z',
#   'batchId': 415,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.620689655172413,
#   'durationMs': {'addBatch': 41,
#    'commitOffsets': 45,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 116,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 415,
#     'endOffset': 416,
#     'latestOffset': 416,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.620689655172413}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:29.316Z',
#   'batchId': 416,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 416,
#     'endOffset': 417,
#     'latestOffset': 417,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:30.319Z',
#   'batchId': 417,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 76,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 417,
#     'endOffset': 418,
#     'latestOffset': 418,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:31.319Z',
#   'batchId': 418,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.0,
#   'durationMs': {'addBatch': 71,
#    'commitOffsets': 84,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 200,
#    'walCommit': 39},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 418,
#     'endOffset': 419,
#     'latestOffset': 419,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:32.319Z',
#   'batchId': 419,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 7.8125,
#   'durationMs': {'addBatch': 36,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 8,
#    'triggerExecution': 128,
#    'walCommit': 42},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 419,
#     'endOffset': 420,
#     'latestOffset': 420,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 7.8125}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:33.318Z',
#   'batchId': 420,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 83,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 420,
#     'endOffset': 421,
#     'latestOffset': 421,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:34.314Z',
#   'batchId': 421,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.345679012345679,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 81,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 421,
#     'endOffset': 422,
#     'latestOffset': 422,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.345679012345679}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:35.319Z',
#   'batchId': 422,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 422,
#     'endOffset': 423,
#     'latestOffset': 423,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:36.313Z',
#   'batchId': 423,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.936507936507937,
#   'durationMs': {'addBatch': 46,
#    'commitOffsets': 46,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 126,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 423,
#     'endOffset': 424,
#     'latestOffset': 424,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.936507936507937}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:37.321Z',
#   'batchId': 424,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 424,
#     'endOffset': 425,
#     'latestOffset': 425,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:38.315Z',
#   'batchId': 425,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 33,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 92,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 425,
#     'endOffset': 426,
#     'latestOffset': 426,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:39.312Z',
#   'batchId': 426,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 77,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 426,
#     'endOffset': 427,
#     'latestOffset': 427,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:40.316Z',
#   'batchId': 427,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 27,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 83,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 427,
#     'endOffset': 428,
#     'latestOffset': 428,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:41.316Z',
#   'batchId': 428,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 428,
#     'endOffset': 429,
#     'latestOffset': 429,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:42.319Z',
#   'batchId': 429,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 429,
#     'endOffset': 430,
#     'latestOffset': 430,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:43.318Z',
#   'batchId': 430,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 2.680965147453083,
#   'durationMs': {'addBatch': 83,
#    'commitOffsets': 247,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 373,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 430,
#     'endOffset': 431,
#     'latestOffset': 431,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 2.680965147453083}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:44.316Z',
#   'batchId': 431,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.547008547008547,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 7,
#    'triggerExecution': 117,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 431,
#     'endOffset': 432,
#     'latestOffset': 432,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.547008547008547}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:45.317Z',
#   'batchId': 432,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.345679012345679,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 81,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 432,
#     'endOffset': 433,
#     'latestOffset': 433,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.345679012345679}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:46.313Z',
#   'batchId': 433,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 76,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 433,
#     'endOffset': 434,
#     'latestOffset': 434,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:47.313Z',
#   'batchId': 434,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 434,
#     'endOffset': 435,
#     'latestOffset': 435,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:48.315Z',
#   'batchId': 435,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.195121951219512,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 25,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 82,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 435,
#     'endOffset': 436,
#     'latestOffset': 436,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.195121951219512}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:49.313Z',
#   'batchId': 436,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 29,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 84,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 436,
#     'endOffset': 437,
#     'latestOffset': 437,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:50.312Z',
#   'batchId': 437,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.064516129032258,
#   'durationMs': {'addBatch': 41,
#    'commitOffsets': 54,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 124,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 437,
#     'endOffset': 438,
#     'latestOffset': 438,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.064516129032258}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:51.319Z',
#   'batchId': 438,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.638297872340425,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 37,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 94,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 438,
#     'endOffset': 439,
#     'latestOffset': 439,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.638297872340425}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:52.317Z',
#   'batchId': 439,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 79,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 439,
#     'endOffset': 440,
#     'latestOffset': 440,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:53.320Z',
#   'batchId': 440,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 440,
#     'endOffset': 441,
#     'latestOffset': 441,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:54.320Z',
#   'batchId': 441,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 83,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 441,
#     'endOffset': 442,
#     'latestOffset': 442,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:55.316Z',
#   'batchId': 442,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.174311926605505,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 109,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 442,
#     'endOffset': 443,
#     'latestOffset': 443,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.174311926605505}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:56.317Z',
#   'batchId': 443,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.4074074074074066,
#   'durationMs': {'addBatch': 50,
#    'commitOffsets': 42,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 135,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 443,
#     'endOffset': 444,
#     'latestOffset': 444,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.4074074074074066}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:57.313Z',
#   'batchId': 444,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.462686567164178,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 51,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 134,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 444,
#     'endOffset': 445,
#     'latestOffset': 445,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.462686567164178}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:58.319Z',
#   'batchId': 445,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.195121951219512,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 82,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 445,
#     'endOffset': 446,
#     'latestOffset': 446,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.195121951219512}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:08:59.313Z',
#   'batchId': 446,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.869565217391305,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 32,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 92,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 446,
#     'endOffset': 447,
#     'latestOffset': 447,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.869565217391305}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:00.320Z',
#   'batchId': 447,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.235955056179776,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 89,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 447,
#     'endOffset': 448,
#     'latestOffset': 448,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.235955056179776}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:01.312Z',
#   'batchId': 448,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.627906976744187,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 86,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 448,
#     'endOffset': 449,
#     'latestOffset': 449,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.627906976744187}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:02.320Z',
#   'batchId': 449,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 449,
#     'endOffset': 450,
#     'latestOffset': 450,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:03.312Z',
#   'batchId': 450,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 77,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 450,
#     'endOffset': 451,
#     'latestOffset': 451,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:04.313Z',
#   'batchId': 451,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.403361344537815,
#   'durationMs': {'addBatch': 45,
#    'commitOffsets': 44,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 119,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 451,
#     'endOffset': 452,
#     'latestOffset': 452,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.403361344537815}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:05.317Z',
#   'batchId': 452,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.345679012345679,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 28,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 3,
#    'triggerExecution': 81,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 452,
#     'endOffset': 453,
#     'latestOffset': 453,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.345679012345679}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:06.319Z',
#   'batchId': 453,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 79,
#    'walCommit': 24},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 453,
#     'endOffset': 454,
#     'latestOffset': 454,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:07.320Z',
#   'batchId': 454,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 9.25925925925926,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 37,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 108,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 454,
#     'endOffset': 455,
#     'latestOffset': 455,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 9.25925925925926}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:08.320Z',
#   'batchId': 455,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.416666666666666,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 36,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 96,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 455,
#     'endOffset': 456,
#     'latestOffset': 456,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.416666666666666}],
# ...
#     'startOffset': 477,
#     'endOffset': 478,
#     'latestOffset': 478,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.620689655172413}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:31.317Z',
#   'batchId': 478,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.928571428571429,
#   'durationMs': {'addBatch': 32,
#    'commitOffsets': 34,
#    'getBatch': 1,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 112,
#    'walCommit': 40},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 478,
#     'endOffset': 479,
#     'latestOffset': 479,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.928571428571429}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:32.312Z',
#   'batchId': 479,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 8.849557522123893,
#   'durationMs': {'addBatch': 43,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 113,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 479,
#     'endOffset': 480,
#     'latestOffset': 480,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 8.849557522123893}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:33.314Z',
#   'batchId': 480,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.5,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 80,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 480,
#     'endOffset': 481,
#     'latestOffset': 481,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.5}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:34.319Z',
#   'batchId': 481,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.987012987012987,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 77,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 481,
#     'endOffset': 482,
#     'latestOffset': 482,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.987012987012987}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:35.311Z',
#   'batchId': 482,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 23,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 3,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 482,
#     'endOffset': 483,
#     'latestOffset': 483,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:36.314Z',
#   'batchId': 483,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 11.904761904761903,
#   'durationMs': {'addBatch': 28,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 84,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 483,
#     'endOffset': 484,
#     'latestOffset': 484,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 11.904761904761903}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:37.313Z',
#   'batchId': 484,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 12.345679012345679,
#   'durationMs': {'addBatch': 26,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 81,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 484,
#     'endOffset': 485,
#     'latestOffset': 485,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 12.345679012345679}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:38.319Z',
#   'batchId': 485,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 9.900990099009901,
#   'durationMs': {'addBatch': 29,
#    'commitOffsets': 41,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 101,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 485,
#     'endOffset': 486,
#     'latestOffset': 486,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 9.900990099009901}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:39.315Z',
#   'batchId': 486,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.692307692307692,
#   'durationMs': {'addBatch': 41,
#    'commitOffsets': 58,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 130,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 486,
#     'endOffset': 487,
#     'latestOffset': 487,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.692307692307692}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:40.320Z',
#   'batchId': 487,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.048192771084336,
#   'durationMs': {'addBatch': 25,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 83,
#    'walCommit': 26},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 487,
#     'endOffset': 488,
#     'latestOffset': 488,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.048192771084336}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:41.319Z',
#   'batchId': 488,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.333333333333334,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 24,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 75,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 488,
#     'endOffset': 489,
#     'latestOffset': 489,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.333333333333334}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:42.317Z',
#   'batchId': 489,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 5.847953216374268,
#   'durationMs': {'addBatch': 39,
#    'commitOffsets': 87,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 171,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 489,
#     'endOffset': 490,
#     'latestOffset': 490,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 5.847953216374268}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:43.318Z',
#   'batchId': 490,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 7.633587786259541,
#   'durationMs': {'addBatch': 40,
#    'commitOffsets': 40,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 6,
#    'triggerExecution': 131,
#    'walCommit': 45},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 490,
#     'endOffset': 491,
#     'latestOffset': 491,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 7.633587786259541}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:44.312Z',
#   'batchId': 491,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 76,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 491,
#     'endOffset': 492,
#     'latestOffset': 492,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:45.311Z',
#   'batchId': 492,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 13.157894736842106,
#   'durationMs': {'addBatch': 21,
#    'commitOffsets': 25,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 76,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 492,
#     'endOffset': 493,
#     'latestOffset': 493,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 13.157894736842106}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:46.314Z',
#   'batchId': 493,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 90.90909090909092,
#   'processedRowsPerSecond': 6.25,
#   'durationMs': {'addBatch': 51,
#    'commitOffsets': 80,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 160,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 493,
#     'endOffset': 494,
#     'latestOffset': 494,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 90.90909090909092,
#     'processedRowsPerSecond': 6.25}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:47.315Z',
#   'batchId': 494,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 10.526315789473685,
#   'durationMs': {'addBatch': 30,
#    'commitOffsets': 35,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 5,
#    'triggerExecution': 95,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 494,
#     'endOffset': 495,
#     'latestOffset': 495,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 10.526315789473685}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:48.313Z',
#   'batchId': 495,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.658227848101266,
#   'durationMs': {'addBatch': 24,
#    'commitOffsets': 26,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 79,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 495,
#     'endOffset': 496,
#     'latestOffset': 496,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.658227848101266}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}},
#  {'id': '55282fdd-6243-4c69-bc54-469305a32070',
#   'runId': '6e2029b1-7729-41b6-afdd-c25a09a5d817',
#   'name': 'rate_report',
#   'timestamp': '2024-11-23T14:09:49.316Z',
#   'batchId': 496,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 100.0,
#   'processedRowsPerSecond': 12.820512820512821,
#   'durationMs': {'addBatch': 22,
#    'commitOffsets': 27,
#    'getBatch': 0,
#    'latestOffset': 0,
#    'queryPlanning': 4,
#    'triggerExecution': 78,
#    'walCommit': 25},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=1, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': 496,
#     'endOffset': 497,
#     'latestOffset': 497,
#     'numInputRows': 1,
#     'inputRowsPerSecond': 100.0,
#     'processedRowsPerSecond': 12.820512820512821}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 1}}]

# %%
query.lastProgress['batchId']
# Out:
# 588

# %% [markdown]
# # Stop streaming

# %%
query.stop()

# %%
spark.sql("select * from rate_report").count()
# Out:
# 589

# %%
# awaitTermination

# %% [markdown]
# # Increase rows per second (rate)

# %%
# read stream
stream = spark.readStream.format("rate").option("rowsPerSecond", 20).load()

transformed = stream.withColumn("value2", F.col("value") * 2)

query = (transformed.writeStream
  .format('memory')
  .queryName('rate_report_2')
  .outputMode('append')
  .start()
)

# %%
print(spark.table("rate_report_2").count())
spark.table("rate_report_2").show(100, False)
# Out:
# 1480
# +-----------------------+-----+------+
# |timestamp              |value|value2|
# +-----------------------+-----+------+
# |2024-11-23 14:13:23.422|0    |0     |
# |2024-11-23 14:13:23.472|1    |2     |
# |2024-11-23 14:13:23.522|2    |4     |
# |2024-11-23 14:13:23.572|3    |6     |
# |2024-11-23 14:13:23.622|4    |8     |
# |2024-11-23 14:13:23.672|5    |10    |
# |2024-11-23 14:13:23.722|6    |12    |
# |2024-11-23 14:13:23.772|7    |14    |
# |2024-11-23 14:13:23.822|8    |16    |
# |2024-11-23 14:13:23.872|9    |18    |
# |2024-11-23 14:13:23.922|10   |20    |
# |2024-11-23 14:13:23.972|11   |22    |
# |2024-11-23 14:13:24.022|12   |24    |
# |2024-11-23 14:13:24.072|13   |26    |
# |2024-11-23 14:13:24.122|14   |28    |
# |2024-11-23 14:13:24.172|15   |30    |
# |2024-11-23 14:13:24.222|16   |32    |
# |2024-11-23 14:13:24.272|17   |34    |
# |2024-11-23 14:13:24.322|18   |36    |
# |2024-11-23 14:13:24.372|19   |38    |
# |2024-11-23 14:13:24.422|20   |40    |
# |2024-11-23 14:13:24.472|21   |42    |
# |2024-11-23 14:13:24.522|22   |44    |
# |2024-11-23 14:13:24.572|23   |46    |
# |2024-11-23 14:13:24.622|24   |48    |
# |2024-11-23 14:13:24.672|25   |50    |
# |2024-11-23 14:13:24.722|26   |52    |
# |2024-11-23 14:13:24.772|27   |54    |
# |2024-11-23 14:13:24.822|28   |56    |
# |2024-11-23 14:13:24.872|29   |58    |
# |2024-11-23 14:13:24.922|30   |60    |
# |2024-11-23 14:13:24.972|31   |62    |
# |2024-11-23 14:13:25.022|32   |64    |
# |2024-11-23 14:13:25.072|33   |66    |
# |2024-11-23 14:13:25.122|34   |68    |
# |2024-11-23 14:13:25.172|35   |70    |
# |2024-11-23 14:13:25.222|36   |72    |
# |2024-11-23 14:13:25.272|37   |74    |
# |2024-11-23 14:13:25.322|38   |76    |
# |2024-11-23 14:13:25.372|39   |78    |
# |2024-11-23 14:13:25.422|40   |80    |
# |2024-11-23 14:13:25.472|41   |82    |
# |2024-11-23 14:13:25.522|42   |84    |
# |2024-11-23 14:13:25.572|43   |86    |
# |2024-11-23 14:13:25.622|44   |88    |
# |2024-11-23 14:13:25.672|45   |90    |
